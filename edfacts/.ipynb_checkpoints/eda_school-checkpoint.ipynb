# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
mydf = pd.read_csv("schools_edfacts_assessments_2009.csv", compression='gzip')

# %%
mydf
# Out:
#           ncessch_num  year                        school_name  leaid_num  \
# 0         10000500870  2009              Ala Avenue Middle Sch     100005
# 1         10000500870  2009              Ala Avenue Middle Sch     100005
# 2         10000500870  2009              Ala Avenue Middle Sch     100005
# 3         10000500870  2009              Ala Avenue Middle Sch     100005
# 4         10000500870  2009              Ala Avenue Middle Sch     100005
# ...               ...   ...                                ...        ...
# 3975608  720003002085  2009  JUAN QUIRINDONGO MORELL(SUPERIOR)    7200030
# 3975609  720003002085  2009  JUAN QUIRINDONGO MORELL(SUPERIOR)    7200030
# 3975610  720003002085  2009  JUAN QUIRINDONGO MORELL(SUPERIOR)    7200030
# 3975611  720003002085  2009  JUAN QUIRINDONGO MORELL(SUPERIOR)    7200030
# 3975612  720003002085  2009  JUAN QUIRINDONGO MORELL(SUPERIOR)    7200030
#
#                                     lea_name  fips  grade_edfacts  race  sex  \
# 0                           Albertville City     1             99    99   99
# 1                           Albertville City     1             99     5   99
# 2                           Albertville City     1             99     4   99
# 3                           Albertville City     1             99     2   99
# 4                           Albertville City     1             99    99   99
# ...                                      ...   ...            ...   ...  ...
# 3975608  PUERTO RICO DEPARTMENT OF EDUCATION    72              9    99   99
# 3975609  PUERTO RICO DEPARTMENT OF EDUCATION    72              9    99   99
# 3975610  PUERTO RICO DEPARTMENT OF EDUCATION    72              9    99    1
# 3975611  PUERTO RICO DEPARTMENT OF EDUCATION    72              9     7   99
# 3975612  PUERTO RICO DEPARTMENT OF EDUCATION    72              9     1   99
#
#          lep  ...  read_test_num_valid  read_test_pct_prof_low  \
# 0         99  ...                511.0                    79.0
# 1         99  ...                  1.0                    -3.0
# 2         99  ...                  2.0                    -3.0
# 3         99  ...                 10.0                    50.0
# 4         99  ...                301.0                    71.0
# ...      ...  ...                  ...                     ...
# 3975608   99  ...                  3.0                    -3.0
# 3975609    1  ...                  0.0                    -2.0
# 3975610   99  ...                 81.0                    30.0
# 3975611   99  ...                  0.0                    -2.0
# 3975612   99  ...                  0.0                    -2.0
#
#          read_test_pct_prof_high  read_test_pct_prof_midpt  \
# 0                           79.0                      79.0
# 1                           -3.0                      -3.0
# 2                           -3.0                      -3.0
# 3                          100.0                      75.0
# 4                           71.0                      71.0
# ...                          ...                       ...
# 3975608                     -3.0                      -3.0
# 3975609                     -2.0                      -2.0
# 3975610                     34.0                      32.0
# 3975611                     -2.0                      -2.0
# 3975612                     -2.0                      -2.0
#
#          math_test_num_valid  math_test_pct_prof_low  math_test_pct_prof_high  \
# 0                      523.0                    76.0                     76.0
# 1                        1.0                    -3.0                     -3.0
# 2                        2.0                    -3.0                     -3.0
# 3                       10.0                    50.0                    100.0
# 4                      308.0                    70.0                     70.0
# ...                      ...                     ...                      ...
# 3975608                  3.0                    -3.0                     -3.0
# 3975609                  0.0                    -2.0                     -2.0
# 3975610                 84.0                     0.0                      5.0
# 3975611                  0.0                    -2.0                     -2.0
# 3975612                  0.0                    -2.0                     -2.0
#
#          math_test_pct_prof_midpt       ncessch    leaid
# 0                            76.0   10000500870   100005
# 1                            -3.0   10000500870   100005
# 2                            -3.0   10000500870   100005
# 3                            75.0   10000500870   100005
# 4                            70.0   10000500870   100005
# ...                           ...           ...      ...
# 3975608                      -3.0  720003002085  7200030
# 3975609                      -2.0  720003002085  7200030
# 3975610                       2.5  720003002085  7200030
# 3975611                      -2.0  720003002085  7200030
# 3975612                      -2.0  720003002085  7200030
#
# [3975613 rows x 26 columns]

# %%
# create a histogram of all Male and female observatins

# can we do it without have
male_female_df = mydf[mydf["sex"] != 99]

#2-D scatter plot:
#ALWAYS understand the axis: labels and scale.

male_female_df.plot(kind='scatter', x='sex', y='math_test_pct_prof_high') ;
plt.show()

#cannot make much sense out it. 
#What if we color the points by thier class-label/flower-type.

# %%
# 2-D Scatter plot with color-coding for each male type/class.
# Here 'sns' corresponds to seaborn. 
sns.set_style("whitegrid");
sns.FacetGrid(male_female_df, hue="sex", size=4) \
   .map(plt.scatter, "math_test_pct_prof_low", "math_test_pct_prof_high") \
   .add_legend();
plt.show();

# Notice that the blue points can be easily seperated 
# Can we draw multiple 2-D scatter plots for each combination of features?
# How many cobinations exist? 4C2 = 6.
# Out:
# /Users/ajp/opt/anaconda3/envs/educationdata/lib/python3.8/site-packages/seaborn/axisgrid.py:316: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
# pairwise scatter plot: Pair-Plot
# Dis-advantages: 
##Can be used when number of features are high.
##Cannot visualize higher dimensional patterns in 3-D and 4-D. 
#Only possible to view 2D patterns.
plt.close();
sns.set_style("whitegrid");
sns.pairplot(male_female_df, hue="sex", size=3);
plt.show()
# NOTE: the diagnol elements are PDFs for each feature. PDFs are expalined below.
# Out:
# /Users/ajp/opt/anaconda3/envs/educationdata/lib/python3.8/site-packages/seaborn/axisgrid.py:1969: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# /Users/ajp/opt/anaconda3/envs/educationdata/lib/python3.8/site-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /Users/ajp/opt/anaconda3/envs/educationdata/lib/python3.8/site-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /Users/ajp/opt/anaconda3/envs/educationdata/lib/python3.8/site-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /Users/ajp/opt/anaconda3/envs/educationdata/lib/python3.8/site-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /Users/ajp/opt/anaconda3/envs/educationdata/lib/python3.8/site-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /Users/ajp/opt/anaconda3/envs/educationdata/lib/python3.8/site-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /Users/ajp/opt/anaconda3/envs/educationdata/lib/python3.8/site-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /Users/ajp/opt/anaconda3/envs/educationdata/lib/python3.8/site-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /Users/ajp/opt/anaconda3/envs/educationdata/lib/python3.8/site-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /Users/ajp/opt/anaconda3/envs/educationdata/lib/python3.8/site-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /Users/ajp/opt/anaconda3/envs/educationdata/lib/python3.8/site-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /Users/ajp/opt/anaconda3/envs/educationdata/lib/python3.8/site-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /Users/ajp/opt/anaconda3/envs/educationdata/lib/python3.8/site-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /Users/ajp/opt/anaconda3/envs/educationdata/lib/python3.8/site-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /Users/ajp/opt/anaconda3/envs/educationdata/lib/python3.8/site-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /Users/ajp/opt/anaconda3/envs/educationdata/lib/python3.8/site-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /Users/ajp/opt/anaconda3/envs/educationdata/lib/python3.8/site-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /Users/ajp/opt/anaconda3/envs/educationdata/lib/python3.8/site-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)

# %%
# What about 1-D scatter plot using just one feature?
#1-D scatter plot of petal-length
import numpy as np
male_df = male_female_df.loc[male_female_df["sex"] == 1];
female_df = male_female_df.loc[male_female_df["sex"] == 2];


plt.plot(male_df["math_test_pct_prof_high"], np.zeros_like(male_df['math_test_pct_prof_high']), 'o')
plt.plot(female_df["math_test_pct_prof_high"], np.zeros_like(female_df['math_test_pct_prof_high']), 'o')

plt.show()
#Disadvantages of 1-D scatter plot: Very hard to make sense as points 
#are overlapping a lot.
#Are there better ways of visualizing 1-D scatter plots?

# %%
sns.FacetGrid(male_female_df, hue="sex", size=5) \
   .map(sns.distplot, "math_test_pct_prof_high") \
   .add_legend();
plt.show();

# %%
sns.FacetGrid(male_female_df, hue="sex", size=5) \
   .map(sns.distplot, "math_test_pct_prof_low") \
   .add_legend();
plt.show();
